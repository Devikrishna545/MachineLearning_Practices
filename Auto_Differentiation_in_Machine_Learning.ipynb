# %% [markdown]
# <a href="https://colab.research.google.com/github/Devikrishna545/MachineLearning_Practices/blob/main/Auto_Differentiation_in_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Auto differentiation using Pytorch

# %% [markdown]
# Here we can do autodifferentiation / auto diff using these libraries.
# y=x^2 ,when x= 5 , find dy/dx?
#
# dy/dx = 2*x =5*2 =10
#
# Now i have to do it using auto diff method.

# %%
#import pytorch
import torch

# %%
#to store value of x as scalar with tensor.
x=torch.tensor(5.0)
x.requires_grad_() # makes requires_grad =  'True' ,it tracks the gradients wherever the x changes in the forward pass.
# Out:
# tensor(5., requires_grad=True)

# %%
#now y =x^2
y = x**2

# %%
y.backward() #to find dy

# %%
x.grad # to find slop
# Out:
# tensor(10.)

# %% [markdown]
# # Auto Differentiation using TensorFlow

# %%
#import tensor flow
import tensorflow as tf

# %%
#to store variable
x=tf.Variable(5.0)
with tf.GradientTape() as t:
  t.watch(x) #track forward
  y= x**2

# %%
t.gradient(y,x) #use autodiff with tensorflow gradient function
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>

# %% [markdown]
# # Practice of autodiff
#
# y=x^2+2x+2 and x=2,Find the slop with pytorch and tensor flow

# %% [markdown]
# #In Pytorch

# %%
x= torch.tensor(2.0)

# %%
x.requires_grad_()
# Out:
# tensor(2., requires_grad=True)

# %%
y= x**2 + 2*x + 2

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %% [markdown]
# # In Tensorflow

# %%
x=tf.Variable(2.0)
with tf.GradientTape() as t:
  t.watch(x)
  y= x**2 + 2*x + 2

# %%
t.gradient(y,x)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=6.0>
